# %% [markdown]
# # Práctica — Documentación con Markdown y análisis SQL
#
# Antes de resolver las consultas, el notebook debe quedar documentado con Markdown.
#
# El objetivo es construir un notebook que pueda leerse como un entregable técnico:
#
# - Qué tabla se ha creado.
# - Qué validaciones se han realizado.
# - Qué pregunta responde cada consulta SQL.
# - Qué resultado se espera.
# - Qué conclusiones se obtienen.
#
# ## Datos de trabajo
#
# | Elemento | Valor |
# |---|---|
# | Dataset | `orders.csv` |
# | Número esperado de filas | 100 |
# | Tabla por pareja | `training.lesson_01.orders_delta_pair_XX` |
# | Lenguaje | SQL |
#
# ## Instrucciones generales
#
# 1. Sustituye `pair_01` por el identificador real de tu pareja.
# 2. Añade una celda Markdown antes de cada consulta SQL.
# 3. Explica qué pregunta resuelve la consulta.
# 4. Ejecuta la consulta.
# 5. Anota si el resultado coincide con lo esperado.

# %% [markdown]
# # Ejercicio previo — Crear la cabecera Markdown del notebook
#
# Añade una celda Markdown al principio del notebook con esta estructura y complétala con tus datos.
#
# ```markdown
# # Ejercicio 1 - Primer análisis SQL en Databricks
#
# **Pareja:** pair_XX
# **Tabla:** training.lesson_01.orders_delta_pair_XX
# **Dataset:** orders.csv
# **Objetivo:** crear una tabla Delta desde un CSV y resolver preguntas de negocio con SQL.
# ```
#
# ## Documenta también la tabla de entrada
#
# Añade una tabla Markdown con las columnas del dataset.
#
# | Columna | Descripción | Tipo esperado |
# |---|---|---|
# | order_id | Identificador del pedido | Numérico |
# | customer_id | Identificador del cliente | Numérico |
# | order_date | Fecha del pedido | Fecha |
# | country | País del pedido | Texto |
# | channel | Canal de venta | Texto |
# | amount | Importe del pedido | Numérico |
# | status | Estado del pedido | Texto |

# %% [markdown]
# ## Ejercicio 1 — Total de pedidos por estado
#
# Pregunta: **¿Cuál es el total de pedidos por estado?**
#
# Objetivo: agrupar los pedidos por `status` y contar cuántos registros hay en cada estado.
#
# Resultado esperado:
#
# | status | total_orders |
# |---|---:|
# | Completed | 64 |
# | Cancelled | 24 |
# | Pending | 12 |

# %%
# Codigo

# %% [markdown]
# ## Ejercicio 2 — Importe total por país
#
# Pregunta: **¿Cuál es el importe total vendido por país?**
#
# Objetivo: sumar la columna `amount` para cada valor de `country`.
#
# Resultado esperado:
#
# | country | total_amount |
# |---|---:|
# | Spain | 9692.02 |
# | France | 8513.42 |
# | Netherlands | 8294.08 |
# | Portugal | 7942.41 |
# | Germany | 6109.17 |
# | Italy | 5408.06 |

# %%
# codigo

# %% [markdown]
# ## Ejercicio 3 — País con mayor importe vendido
#
# Pregunta: **¿Cuál es el país con mayor importe vendido?**
#
# Objetivo: obtener el país con mayor suma de `amount`.
#
# Resultado esperado:
#
# | country | total_amount |
# |---|---:|
# | Spain | 9692.02 |

# %%
# codigo

# %% [markdown]
# ## Ejercicio 4 — Ticket medio por canal
#
# Pregunta: **¿Cuál es el ticket medio por canal?**
#
# Objetivo: calcular el promedio de `amount` para cada canal de venta.
#
# Resultado esperado:
#
# | channel | average_order_amount |
# |---|---:|
# | Online | 526.77 |
# | Marketplace | 497.29 |
# | Partner | 432.85 |
# | Store | 349.40 |

# %%
# codigo

# %% [markdown]
# ## Ejercicio 5 — Pedidos cancelados por país
#
# Pregunta: **¿Cuál es el número de pedidos cancelados por país?**
#
# Objetivo: filtrar los pedidos con `status = 'Cancelled'` y contarlos por país.
#
# Resultado esperado:
#
# | country | cancelled_orders |
# |---|---:|
# | Spain | 7 |
# | Netherlands | 5 |
# | France | 4 |
# | Italy | 4 |
# | Portugal | 3 |
# | Germany | 1 |

# %%
# codigo

# %% [markdown]
# ## Ejercicio 6 — Ventas por día
#
# Pregunta: **¿Cuál es el número de pedidos y el importe total vendido por día?**
#
# Objetivo: agrupar por `order_date`, contar pedidos y sumar importes.
#
# Resultado esperado: la consulta debe devolver **31 filas**, una por cada día de enero de 2026.

# %%
# codigo

# %% [markdown]
# ## Ejercicio 7 — Canales con más de 10 pedidos
#
# Pregunta: **¿Qué canales tienen más de 10 pedidos?**
#
# Objetivo: agrupar por `channel`, contar pedidos y conservar solo los canales con más de 10 registros mediante `HAVING`.
#
# Resultado esperado:
#
# | channel | total_orders | total_amount |
# |---|---:|---:|
# | Partner | 30 | 12985.38 |
# | Online | 28 | 14749.60 |
# | Marketplace | 24 | 11934.93 |
# | Store | 18 | 6289.25 |

# %% [markdown]
# ## Ejercicio 8 — Comprobación de nulos
#
# Pregunta: **¿Existen valores nulos en las columnas principales?**
#
# Objetivo: comprobar si alguna de las columnas principales contiene valores nulos.
#
# Resultado esperado: todas las columnas deben devolver **0 nulos**.

# %%
# codigo. Puedes usar Genie Code.

# %% [markdown]
# # Bloque adicional — Ejercicios con widgets
#
# En esta sección se trabaja con parámetros para evitar reescribir la misma consulta muchas veces.
#
# Los widgets permiten cambiar valores desde la parte superior del notebook y volver a ejecutar la consulta.
#
# Antes de empezar, revisa que tu tabla se llama con este patrón:
#
# ```text
# training.lesson_01.orders_delta_pair_XX
# ```
#
# Sustituye el valor del widget `table_name` por el nombre real de tu tabla.

# %% [markdown]
# ## Crear widgets de trabajo
#
# Ejecuta las siguientes celdas para crear los parámetros del notebook.
#
# Después modifica los valores desde la barra superior de widgets.

# %% [markdown]
# ## Ejercicio 9 — Filtrar pedidos con widgets
#
# Pregunta: **¿Cuántos pedidos hay para el país, estado e importe mínimo seleccionados?**
#
# Cambia los widgets `selected_country`, `selected_status` y `minimum_amount`, y vuelve a ejecutar la consulta.
#
# Resultado esperado con valores por defecto:
#
# | selected_country | selected_status | minimum_amount |
# |---|---|---:|
# | Spain | Completed | 0 |

# %%
# codigo. Puedes utilizar genie code.

# %% [markdown]
# ## Ejercicio 10 — Analizar canales con el país seleccionado
#
# Pregunta: **¿Cuál es el total de pedidos e importe por canal para el país seleccionado?**
#
# Usa el widget `selected_country`.
#
# Cambia el país y observa cómo cambia el resultado.

# %%
# codigo. Puedes utilizar genie code.

# %% [markdown]
# ## Ejercicio 11 — Analizar estados con importe mínimo
#
# Pregunta: **¿Cuál es el total de pedidos por estado para pedidos con importe igual o superior al mínimo seleccionado?**
#
# Usa el widget `minimum_amount`.
#
# Prueba al menos estos valores:
#
# - `0`
# - `250`
# - `500`
# - `750`

# %%
# codigo. Puedes utilizar genie code.

# %% [markdown]
# ## Ejercicio 12 — Consulta parametrizada final
#
# Pregunta: **¿Cuál es el detalle diario de pedidos para el país, estado e importe mínimo seleccionados?**
#
# Esta consulta combina los tres widgets principales.
#
# Debe devolver resultados distintos cuando cambias los parámetros.

# %%
# codigo. Puedes utilizar genie code.

# %% [markdown]
# ## Checklist adicional de widgets
#
# | Validación | Estado |
# |---|---|
# | Widget `table_name` creado | Hecho / Pendiente |
# | Widget `selected_country` creado | Hecho / Pendiente |
# | Widget `selected_status` creado | Hecho / Pendiente |
# | Widget `minimum_amount` creado | Hecho / Pendiente |
# | Se ejecutó una consulta con `:selected_country` | Hecho / Pendiente |
# | Se ejecutó una consulta con `:selected_status` | Hecho / Pendiente |
# | Se ejecutó una consulta con `:minimum_amount` | Hecho / Pendiente |
# | Se cambió al menos un widget y se reejecutó una consulta | Hecho / Pendiente |
# | Se usó `IDENTIFIER(:table_name)` para consultar la tabla parametrizada | Hecho / Pendiente |

# %% [markdown]
# # Checklist final de entrega
#
# Completa esta checklist al final del notebook.
#
# | Validación | Estado |
# |---|---|
# | Tabla creada desde CSV usando la interfaz | Hecho / Pendiente |
# | Tabla creada en `training.lesson_01` | Hecho / Pendiente |
# | Nombre de tabla incluye `pair_XX` | Hecho / Pendiente |
# | La tabla contiene 100 filas | Hecho / Pendiente |
# | La tabla tiene las 7 columnas esperadas | Hecho / Pendiente |
# | Se resolvió el total de pedidos por estado | Hecho / Pendiente |
# | Se resolvió el importe total por país | Hecho / Pendiente |
# | Se identificó el país con mayor venta | Hecho / Pendiente |
# | Se calculó el ticket medio por canal | Hecho / Pendiente |
# | Se calcularon pedidos cancelados por país | Hecho / Pendiente |
# | Se calcularon ventas por día | Hecho / Pendiente |
# | Se identificaron canales con más de 10 pedidos | Hecho / Pendiente |
# | Se comprobaron valores nulos | Hecho / Pendiente |
#
# ## Resumen final
#
# Completa este bloque con tus resultados.
#
# ```text
# Pair ID:
# Table name:
# Total rows:
# Completed orders:
# Cancelled orders:
# Pending orders:
# Country with highest sales:
# Channel with highest average ticket:
# Null check result:
# Main issue found:
# ```
